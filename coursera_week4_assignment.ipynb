# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jeremie Werner**<br>
# Research scientist

# %% [markdown]
# *I am interested in data science to improve my skills and ability to understand large sets of data and make an impact on the deployment of renewable energies.*

# %% [markdown]
# ### my code in Cell5 will print "Hi All!"

# %%
print("Hi All!")
# Out:
# Hi All!

# %% [markdown]
# ***
# - bullet1
# - bullet2
# - bullet3
#
# 1. item1
# 2. item2
# 3. item3
#     * subitem1
#     * subitem2
#
# | table header1 | table header2 |
# | ------ | ------ |
# | something | something else |
